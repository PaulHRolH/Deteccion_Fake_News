# %%
import pandas as pd
import re
import warnings
import string
import joblib
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup, MarkupResemblesLocatorWarning
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc
from xgboost import XGBClassifier
warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)

# %% [markdown]
# ## Funciones

# %%
ps = PorterStemmer()

# %%
def clean_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text(separator=" ", strip=True)

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    text = url_pattern.sub(r'', text)
    return text

# %%
def eliminate_punctuation(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub('[\u2018\u2019\u201C\u201D\u2013\u2014\u2026]', '', text)
    return text

# %%
def stopword_removal(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(filtered_tokens)

# %%
def lemmatization(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [ps.stem(word) for word in tokens]
    return ' '.join(lemmatized_tokens)

# %%
def clean_text(text):
    text = clean_html(text)
    text = remove_urls(text)
    text = eliminate_punctuation(text)
    text = stopword_removal(text)
    text = lemmatization(text)
    
    return text

# %% [markdown]
# ## Exploracion de datos

# %%
seed = 666
np.random.seed(seed)

# %%
df_fake = pd.read_csv('/home/paul-h-roldan-hernandez/Documentos/Scripts/Deteccion_Noticias_Falsas/Fake_Real_News_Dataset/Fake.csv')
df_true = pd.read_csv('/home/paul-h-roldan-hernandez/Documentos/Scripts/Deteccion_Noticias_Falsas/Fake_Real_News_Dataset/True.csv')

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
print(df_true.shape)
print(df_fake.shape)
# Out:
# (21417, 4)
# (23481, 4)

# %%
df_true.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_fake.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_true.sample(10)
# Out:
#                                                    title  \
# 13149  Brazilian prosecutor accuses ex-minister, cong...
# 5548   Trump tax plan to help businesses, working Ame...
# 16167  China aims to set up state anti-corruption uni...
# 19877  Singaporeans protest against uncontested presi...
# 15431   Assad says Syria war does not end in Deir al-Zor
# 14441  Zimbabwe war vets threaten to unleash crowds o...
# 29     Senate leader McConnell sees a more collegial ...
# 17324  Britain and France to work to enforce Iran nuc...
# 15822  Spanish judge orders Catalan leaders to be hel...
# 9961   Senate Democrats want changes to House Republi...
#
#                                                     text       subject  \
# 13149  SAO PAULO (Reuters) - Brazil s prosecutor gene...     worldnews
# 5548   WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
# 16167  BEIJING (Reuters) - China aims to pass a natio...     worldnews
# 19877  SINGAPORE (Reuters) - Hundreds of Singaporeans...     worldnews
# 15431  BEIRUT (Reuters) - Syria s army and its allies...     worldnews
# 14441  HARARE (Reuters) - The leader of Zimbabwe s po...     worldnews
# 29     WASHINGTON (Reuters) - U.S. Senate Majority Le...  politicsNews
# 17324  LONDON (Reuters) - Britain and France are firm...     worldnews
# 15822  MADRID (Reuters) - A Spanish judge on Thursday...     worldnews
# 9961   WASHINGTON (Reuters) - U.S. Senate Minority Le...  politicsNews
#
#                       date
# 13149    December 5, 2017
# 5548     February 9, 2017
# 16167    October 29, 2017
# 19877  September 16, 2017
# 15431    November 7, 2017
# 14441   November 19, 2017
# 29      December 22, 2017
# 17324    October 16, 2017
# 15822    November 2, 2017
# 9961       April 13, 2016

# %%
df_fake.sample(10)
# Out:
#                                                    title  \
# 2305    Photo Of Hillary Reading About Pence’s Privat...
# 14549  HYSTERICAL! HILLARY CLINTON Upstaged By Man Be...
# 18367  TRUMP SUPPORTER’S HILARIOUS VIRAL VIDEO Mockin...
# 10691  “DRIVE THEM OUT OF YOUR PLACES OF WORSHIP!” Lo...
# 17352  HAPPY MOTHER’S DAY…Your First Grader Just Rate...
# 3153    Trump Just ADMITTED He Mindlessly Parrots Rus...
# 14891  SHOCKING: Sharia Law Implemented In First Amer...
# 14722  Desperation? The Clinton Grifters Go Back On T...
# 22840        ‘Trump, Russia, Possible Collusion’ (REMIX)
# 6618    House Republicans Just Went After Your Retire...
#
#                                                     text          subject  \
# 2305   You remember that one company that used to stu...             News
# 14549  A man with stickers on his face must have been...         politics
# 18367  Terrance Williams is a conservative Trump supp...        left-news
# 10691  President Trump gave a powerful speech to Arab...         politics
# 17352  Rate your mom for Mother s Day sounds like the...  Government News
# 3153   Donald Trump once said that he loves  the poor...             News
# 14891  We live near this once great tourist destinati...         politics
# 14722  The World Class Grifters aka The Clintons are ...         politics
# 22840  Russiagate. First it was Russian hacking our e...      Middle-east
# 6618   On Thursday Republicans in Congress voted to o...             News
#
#                   date
# 2305     March 4, 2017
# 14549      Feb 2, 2016
# 18367      Jul 7, 2017
# 10691      Jun 6, 2017
# 17352     May 11, 2015
# 3153   January 5, 2017
# 14891     Nov 25, 2015
# 14722      Jan 2, 2016
# 22840    July 28, 2017
# 6618    April 30, 2016

# %% [markdown]
# ## Preprocesamiento de datos

# %%
df_fake['label'] = 1
df_true['label'] = 0

# %%
df = pd.concat([df_true, df_fake], axis=0).reset_index(drop=True)

# %%
df.sample(20)
# Out:
#                                                    title  \
# 19438  EU officials reach draft deal on more North Ko...
# 36214  HISPANIC ACTIVISTS Promise To Punish Donald Tr...
# 18669  Last flight departs as Iraq imposes ban for Ku...
# 32188  “Rise From Your Knees!” Poland’s Prime Ministe...
# 34880  GREAT SPEECH! DONALD TRUMP Gets A Dig At Hilla...
# 22739   Officer Who Shot Tamir Rice Finally Fired, Bu...
# 26050   Leaked Emails Show Colin Powell Has STRONG Op...
# 227         Trump urges Alabama voters to back Roy Moore
# 22289   US Experiences Surge In Hate-Based Incidents ...
# 28915   Trump Supporters Form Militia To Beat Up Prot...
# 25200   Bernie Sanders Rises In The Senate, Prepares ...
# 36417  State Dept. Releases 7,000 Clinton E-mails But...
# 16757  EU Commission says it has not changed its posi...
# 38083  OUCH! $15 MINIMUM WAGE ACTIVIST Interviewed By...
# 40094  KELLYANNE CONWAY: “Where The Hell Were Those D...
# 4727   Trump to nominate businessman Hagerty as Japan...
# 37421  BUSTED! H.R. McMaster Caught Communicating Int...
# 2619   Ex-CIA head says Trump remarks on Russia inter...
# 36833  HEY SOCIALIST BERNIE SANDERS FANS: CHECK OUT T...
# 19310  Shelling across Pakistan-India border kills si...
#
#                                                     text          subject  \
# 19438  BRUSSELS (Reuters) - EU ambassadors have reach...        worldnews
# 36214  Did you know that a record number of illegals ...         politics
# 18669  ERBIL, Iraq/ANKARA (Reuters) - The last intern...        worldnews
# 32188  Bravo! Polish prime minister Beata Szydlo just...         politics
# 34880  If you watched Trumps acceptance speech last n...         politics
# 22739  After more than two years, the Cleveland polic...             News
# 26050  Colin Powell is NOT voting for Donald Trump, a...             News
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44115  The White House and The Theatrics of ‘Gun Cont...
# 44116  Activists or Terrorists? How Media Controls an...
# 44117  BOILER ROOM – No Surrender, No Retreat, Heads ...
# 44118  Federal Showdown Looms in Oregon After BLM Abu...
# 44119  A Troubled King: Chicago’s Rahm Emanuel Desper...
#
#                                                     text       subject  \
# 0      washington reuter head conserv republican fact...  politicsNews
# 1      washington reuter transgend peopl allow first ...  politicsNews
# 2      washington reuter special counsel investig lin...  politicsNews
# 3      washington reuter trump campaign advis georg p...  politicsNews
# 4      seattlewashington reuter presid donald trump c...  politicsNews
# ...                                                  ...           ...
# 44115  21st centuri wire say world stage men women me...       US_News
# 44116  randi johnson 21st centuri wireth major mainst...       US_News
# 44117  tune altern current radio network acr anoth li...       US_News
# 44118  21st centuri wire say new front open long batt...       US_News
# 44119  21st centuri wire say far away guess want run ...       US_News
#
#                      date  label
# 0      December 31, 2017       0
# 1      December 29, 2017       0
# 2      December 31, 2017       0
# 3      December 30, 2017       0
# 4      December 29, 2017       0
# ...                   ...    ...
# 44115     January 7, 2016      1
# 44116     January 7, 2016      1
# 44117     January 6, 2016      1
# 44118     January 4, 2016      1
# 44119     January 2, 2016      1
#
# [38431 rows x 5 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(df_text_cleaned['text'], df_text_cleaned['label'], test_size=0.3, random_state=seed)

# %%
vectorizer = TfidfVectorizer()
x_train = vectorizer.fit_transform(x_train)
x_test = vectorizer.transform(x_test)

# %% [markdown]
# ## Modelos

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, n_jobs=-1),
    'SVC':                 SVC(probability=True),
    'XGBoost':             XGBClassifier(eval_metric='logloss', n_jobs=-1, device ='cuda', random_state=seed)
}

results = {}
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_prob = model.predict_proba(x_test)[:, 1]
    results[name] = {
        'model':  model,
        'y_pred': y_pred,
        'y_prob': y_prob
    }
# Out:
# /home/paul-h-roldan-hernandez/Diplo_env/lib/python3.12/site-packages/xgboost/core.py:729: UserWarning: [17:48:16] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)

# %%
results
# Out:
# {'Logistic Regression': {'model': LogisticRegression(max_iter=1000, n_jobs=-1),
#   'y_pred': array([0, 0, 0, ..., 1, 1, 0]),
#   'y_prob': array([0.01950481, 0.13530978, 0.00476687, ..., 0.99765893, 0.85634152,
#          0.03002872])},
#  'SVC': {'model': SVC(probability=True),
#   'y_pred': array([0, 0, 0, ..., 1, 1, 0]),
#   'y_prob': array([4.69783813e-05, 3.05678597e-03, 4.73772401e-06, ...,
#          1.00000000e+00, 9.99998709e-01, 3.42172452e-05])},
#  'XGBoost': {'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric='logloss',
#                 feature_types=None, feature_weights=None, gamma=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, ...),
#   'y_pred': array([0, 0, 0, ..., 1, 1, 0]),
#   'y_prob': array([2.8216717e-05, 1.3198955e-03, 2.8174176e-05, ..., 9.9999738e-01,
#          9.9999332e-01, 2.9037255e-04], dtype=float32)}}

# %%
roc_data = []
for name, result in results.items():
    fpr, tpr, _ = roc_curve(y_test, result['y_prob'])
    roc_auc = auc(fpr, tpr)
    for f, t in zip(fpr, tpr):
        roc_data.append({'FPR': f, 'TPR': t, 'Model': f'{name} (AUC = {roc_auc:.3f})'})

roc_df = pd.DataFrame(roc_data)

fig = px.line(
    roc_df, x='FPR', y='TPR', color='Model',
    title='ROC Curves — Model Comparison',
    labels={'FPR': 'False Positive Rate', 'TPR': 'True Positive Rate'}
)
fig.add_shape(type='line', x0=0, y0=0, x1=1, y1=1,
              line=dict(dash='dash', color='gray', width=1))
fig.show()

# %%
results_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Accuracy': [accuracy_score(y_test, result['y_pred']) for result in results.values()]
})

# %%
results_df
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.983955
# 1                  SVC  0.989939
# 2              XGBoost  0.996791

# %%
logistic_model = results['Logistic Regression']['model']

# %%
feature_names = vectorizer.get_feature_names_out()
coef = logistic_model.coef_[0]

df_coef = pd.DataFrame({
    "word": feature_names,
    "coef": coef
})

# %%
df_coef_sorted_fake = df_coef.sort_values(by="coef", ascending=False).head(10)
df_coef_sorted_real = df_coef.sort_values(by="coef", ascending=True).head(10)

# %%
df_coef_sorted_fake
# Out:
#             word      coef
# 144354       via  8.345530
# 67248       imag  8.171548
# 58564        gop  4.769958
# 49352       even  4.449623
# 15545   american  4.304059
# 88916         mr  4.170825
# 63957    hillari  4.146054
# 79463       like  3.783152
# 15472    america  3.605175
# 94691      obama  3.271759

# %%
df_coef_sorted_real
# Out:
#               word       coef
# 115827      reuter -21.496358
# 118977        said -19.575692
# 147224   wednesday  -5.624015
# 146423  washington  -5.612367
# 143117          us  -5.334457
# 140023     tuesday  -5.189169
# 136282    thursday  -4.808837
# 55403       friday  -4.636949
# 87692       monday  -4.517033
# 86654       minist  -4.241837

# %%
plt.figure(figsize=(8, 8))
plt.barh(df_coef_sorted_fake["word"], df_coef_sorted_fake["coef"])
plt.title("Palabras más asociadas a Fake News - Logistic Regression")
plt.xlabel("Coeficiente")
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.barh(df_coef_sorted_real["word"], df_coef_sorted_real["coef"])
plt.title("Palabras más asociadas a True News - Logistic Regression")
plt.xlabel("Coeficiente")
plt.show()

# %% [markdown]
# ### Podemos ver que los modelos aprendieron bastantes palabras sospechsosas propias del dataset y que podrian no ayudar en realidad a detectar fake news

# %%
words_to_check = ["via", "imag", "reuter", "said", "washington"]

for word in words_to_check:
    print(f"\nPalabra: {word}")
    print(
        df_text_cleaned
        .assign(contains_word=df_text_cleaned["text"].str.contains(fr"\b{word}\b", regex=True))
        .groupby("label")["contains_word"]
        .mean()
    )
# Out:
# Palabra: via
# label
# 0    0.021913
# 1    0.501639
# Name: contains_word, dtype: float64
#
# Palabra: imag
# label
# 0    0.022055
# 1    0.524004
# Name: contains_word, dtype: float64
#
# Palabra: reuter
# label
# 0    0.997718
# 1    0.009889
# Name: contains_word, dtype: float64
#
# Palabra: said
# label
# 0    0.936971
# 1    0.554821
# Name: contains_word, dtype: float64
#
# Palabra: washington
# label
# 0    0.407311
# 1    0.127810
# Name: contains_word, dtype: float64
